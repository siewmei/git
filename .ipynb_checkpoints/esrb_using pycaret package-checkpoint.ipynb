# %%
pip install pycaret shap
# Out:
# Collecting pycaretNote: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\siewm\anaconda3\python.exe' 'C:\Users\siewm\AppData\Local\Temp\pip-standalone-pip-y_2w780i\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\siewm\AppData\Local\Temp\pip-build-env-n5wxinaq\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (593 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-59.6.0-py3-none-any.whl (952 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.25-py2.py3-none-any.whl (983 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.7.3-cp39-cp39-win_amd64.whl (34.3 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\siewm\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\siewm\AppData\Local\Temp\pip-wheel-5k52cdpw'
#          cwd: C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\
#     Complete output (268 lines):
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#   Using cached pycaret-2.3.5-py3-none-any.whl (288 kB)
# Collecting shap
#   Using cached shap-0.40.0-cp39-cp39-win_amd64.whl (432 kB)
# Collecting cufflinks>=0.17.0
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Requirement already satisfied: seaborn in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (0.11.2)
# Collecting Boruta
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# Requirement already satisfied: nltk in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (3.6.5)
# Collecting scipy<=1.5.4
#   Using cached scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# Requirement already satisfied: pandas in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (1.3.4)
# Collecting spacy<2.4.0
#   Using cached spacy-2.3.7-cp39-cp39-win_amd64.whl (9.4 MB)
# Requirement already satisfied: joblib in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (1.1.0)
# Collecting pyod
#   Using cached pyod-0.9.5-py3-none-any.whl
# Collecting umap-learn
#   Using cached umap_learn-0.5.2-py3-none-any.whl
# Collecting kmodes>=0.10.1
#   Using cached kmodes-0.11.1-py2.py3-none-any.whl (19 kB)
# Collecting imbalanced-learn==0.7.0
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Collecting scikit-plot
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
# Collecting yellowbrick>=1.0.1
#   Using cached yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting plotly>=4.4.1
#   Using cached plotly-5.4.0-py2.py3-none-any.whl (25.3 MB)
# Collecting pandas-profiling>=2.8.0
#   Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting pycaret
#   Using cached pycaret-2.3.4-py3-none-any.whl (266 kB)
# Collecting numba<0.54
#   Using cached numba-0.53.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting pycaret
#   Using cached pycaret-2.3.3-py3-none-any.whl (264 kB)
#   Using cached pycaret-2.3.2-py3-none-any.whl (263 kB)
#   Using cached pycaret-2.3.1-py3-none-any.whl (261 kB)
#   Using cached pycaret-2.3.0-py3-none-any.whl (261 kB)
# Collecting imbalanced-learn>=0.7.0
#   Using cached imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
# Collecting gensim
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\siewm\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\siewm\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#   Using cached gensim-4.1.2-cp39-cp39-win_amd64.whl (24.0 MB)
# Collecting pycaret
#   Using cached pycaret-2.2.3-py3-none-any.whl (249 kB)
# Collecting spacy
#   Using cached spacy-3.2.1-cp39-cp39-win_amd64.whl (11.8 MB)
# Collecting mlflow
#   Using cached mlflow-1.22.0-py3-none-any.whl (15.5 MB)
# Collecting catboost>=0.23.2
#   Using cached catboost-1.0.3-cp39-none-win_amd64.whl (77.3 MB)
# Collecting pycaret
#   Using cached pycaret-2.2.2-py3-none-any.whl (249 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (0.24.2)
# Requirement already satisfied: matplotlib in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (3.4.3)
# Collecting mlxtend
#   Using cached mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: IPython in c:\users\siewm\appdata\roaming\python\python39\site-packages (from pycaret) (7.24.1)
# Collecting xgboost>=1.1.0
#   Using cached xgboost-1.5.1-py3-none-win_amd64.whl (106.6 MB)
# Requirement already satisfied: ipywidgets in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Collecting lightgbm>=2.3.1
#   Using cached lightgbm-3.3.1-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\siewm\anaconda3\lib\site-packages (from pycaret) (1.20.3)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in c:\users\siewm\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: scipy in c:\users\siewm\anaconda3\lib\site-packages (from shap) (1.7.1)
# Requirement already satisfied: packaging>20.9 in c:\users\siewm\anaconda3\lib\site-packages (from shap) (21.0)
# Requirement already satisfied: numba in c:\users\siewm\anaconda3\lib\site-packages (from shap) (0.54.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\siewm\anaconda3\lib\site-packages (from shap) (4.62.3)
# Requirement already satisfied: six in c:\users\siewm\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.16.0)
# Collecting graphviz
#   Using cached graphviz-0.19.1-py3-none-any.whl (46 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\siewm\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (58.0.4)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: pygments in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (2.9.0)
# Requirement already satisfied: colorama in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.4.4)
# Requirement already satisfied: traitlets>=4.2 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (5.0.5)
# Requirement already satisfied: decorator in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (5.0.9)
# Requirement already satisfied: jedi>=0.16 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.18.0)
# Requirement already satisfied: backcall in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (3.0.18)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\siewm\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from ipywidgets->pycaret) (5.5.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\siewm\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\siewm\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: jupyter-client in c:\users\siewm\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.2)
# Requirement already satisfied: wheel in c:\users\siewm\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.0)
# Requirement already satisfied: jupyter-core in c:\users\siewm\appdata\roaming\python\python39\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\siewm\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\siewm\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\siewm\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\siewm\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\siewm\anaconda3\lib\site-packages (from pandas->pycaret) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\siewm\anaconda3\lib\site-packages (from pandas->pycaret) (2.8.2)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Collecting markupsafe~=2.0.1
#   Using cached MarkupSafe-2.0.1-cp39-cp39-win_amd64.whl (14 kB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\siewm\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.11.3)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.0-cp39-cp39-win_amd64.whl (659 kB)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.6-py3-none-any.whl (9.4 kB)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.8.2-cp39-cp39-win_amd64.whl (1.9 MB)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.0-py3-none-any.whl (8.8 kB)
# Collecting tangled-up-in-unicode==0.1.0
#   Using cached tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\siewm\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.26.0)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\siewm\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (6.0)
# Collecting joblib
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Requirement already satisfied: networkx>=2.4 in c:\users\siewm\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.6.3)
# Requirement already satisfied: Pillow in c:\users\siewm\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (8.4.0)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\siewm\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\siewm\anaconda3\lib\site-packages (from matplotlib->pycaret) (0.10.0)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in c:\users\siewm\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\siewm\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\siewm\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\siewm\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\siewm\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\siewm\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\siewm\anaconda3\lib\site-packages (from scikit-learn>=0.23.2->pycaret) (2.2.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\siewm\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.5)
# Requirement already satisfied: argon2-cffi in c:\users\siewm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\siewm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.11.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\siewm\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (22.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\siewm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.9.4)
# Requirement already satisfied: nbconvert in c:\users\siewm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\siewm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\siewm\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->pycaret) (228)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\siewm\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.7)
# Collecting numpy>=1.17
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\siewm\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\siewm\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.20)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting Cython==0.29.23
#   Using cached Cython-0.29.23-cp39-cp39-win_amd64.whl (1.7 MB)
# Requirement already satisfied: PyWavelets in c:\users\siewm\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.1.1)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.16.2-py3-none-any.whl
# Collecting alembic<=1.4.1
#   Using cached alembic-1.4.1-py2.py3-none-any.whl
# Collecting waitress
#   Using cached waitress-2.0.0-py3-none-any.whl (56 kB)
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.24-py3-none-any.whl (180 kB)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Requirement already satisfied: protobuf>=3.7.0 in c:\users\siewm\anaconda3\lib\site-packages (from mlflow->pycaret) (3.19.1)
# Requirement already satisfied: entrypoints in c:\users\siewm\anaconda3\lib\site-packages (from mlflow->pycaret) (0.3)
# Requirement already satisfied: Flask in c:\users\siewm\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Requirement already satisfied: sqlalchemy in c:\users\siewm\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.22)
# Requirement already satisfied: click>=7.0 in c:\users\siewm\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.3)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.18.6-py3-none-any.whl (17 kB)
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\users\siewm\anaconda3\lib\site-packages (from mlflow->pycaret) (4.8.1)
# Collecting python-editor>=0.3
#   Using cached python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting Mako
#   Using cached Mako-1.1.6-py2.py3-none-any.whl (75 kB)
# Collecting tabulate>=0.7.7
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting websocket-client>=0.32.0
#   Using cached websocket_client-1.2.3-py3-none-any.whl (53 kB)
# Collecting pywin32>=1.0
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\siewm\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\siewm\anaconda3\lib\site-packages (from sqlalchemy->mlflow->pycaret) (1.1.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\siewm\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\siewm\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.4.3)
# Requirement already satisfied: bleach in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: testpath in c:\users\siewm\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: async-generator in c:\users\siewm\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\siewm\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\siewm\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\siewm\anaconda3\lib\site-packages (from nltk->pycaret) (2021.8.3)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\siewm\anaconda3\lib\site-packages (from numba->shap) (0.37.0)
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: numexpr in c:\users\siewm\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.7.3)
# Requirement already satisfied: future in c:\users\siewm\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.0.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Using cached pyLDAvis-3.2.2-py2.py3-none-any.whl
# Collecting funcy
#   Using cached funcy-1.16-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: statsmodels in c:\users\siewm\anaconda3\lib\site-packages (from pyod->pycaret) (0.12.2)
# Collecting srsly<3.0.0,>=2.4.1
#   Using cached srsly-2.4.2-cp39-cp39-win_amd64.whl (451 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.9.0-py3-none-any.whl (25 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-win_amd64.whl (112 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Using cached spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.6-cp39-cp39-win_amd64.whl (21 kB)
# Collecting thinc<8.1.0,>=8.0.12
#   Using cached thinc-8.0.13-cp39-cp39-win_amd64.whl (1.0 MB)
# Collecting blis<0.8.0,>=0.4.0
#   Using cached blis-0.7.5-cp39-cp39-win_amd64.whl (6.6 MB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.1-py3-none-any.whl (42 kB)
# Requirement already satisfied: patsy>=0.5 in c:\users\siewm\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.5-py3-none-any.whl
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: pywin32, markupsafe, numpy, tangled-up-in-unicode, smmap, murmurhash, multimethod, joblib, cymem, catalogue, websocket-client, wasabi, visions, typer, tenacity, tabulate, srsly, smart-open, python-editor, pydantic, preshed, Mako, imagehash, gitdb, blis, waitress, thinc, sqlparse, spacy-loggers, spacy-legacy, querystring-parser, pynndescent, prometheus-flask-exporter, plotly, phik, pathy, missingno, langcodes, htmlmin, graphviz, gitpython, funcy, docker, databricks-cli, Cython, colorlover, alembic, yellowbrick, xgboost, wordcloud, umap-learn, textblob, spacy, slicer, scikit-plot, pyod, pyLDAvis, pandas-profiling, mlxtend, mlflow, lightgbm, kmodes, imbalanced-learn, gensim, cufflinks, catboost, shap, pycaret
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 228
#     Uninstalling pywin32-228:
#       Successfully uninstalled pywin32-228
#   Rolling back uninstall of pywin32
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\siewm\AppData\Local\Temp\pip-uninstall-ks0ly724\pythoncom.cpython-39.pyc
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\siewm\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\isapi
#    from C:\Users\siewm\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\siewm\AppData\Local\Temp\pip-uninstall-4i69r6rc\pythoncom.py
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\siewm\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\pywin32-228-py3.9.egg-info
#    from C:\Users\siewm\anaconda3\Lib\site-packages\~ywin32-228-py3.9.egg-info
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\siewm\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\win32com
#    from C:\Users\siewm\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\siewm\anaconda3\lib\site-packages\win32comext
#    from C:\Users\siewm\anaconda3\Lib\site-packages\~in32comext
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\siewm\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\siewm\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\siewm\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     C:\Users\siewm\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\siewm\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c
#     Complete output (10 lines):
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'C:\Users\siewm\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\siewm\AppData\Local\Temp\pip-record-921_n2dd\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\siewm\AppData\Local\Temp\pip-build-env-n5wxinaq\overlay' --compile --install-headers 'C:\Users\siewm\AppData\Local\Temp\pip-build-env-n5wxinaq\overlay\Include\numpy'
#            cwd: C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\
#       Complete output (273 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blis not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       accelerate_info:
#         NOT AVAILABLE
#
#       C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       flame_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries flame not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\siewm\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\siewm\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\siewm\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\siewm\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\siewm\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\siewm\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['C:\\Users\\siewm\\anaconda3\\lib', 'C:\\', 'C:\\Users\\siewm\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\siewm\AppData\Local\Temp\pip-install-jlgwmy0b\numpy_6a901911fe86464997ec77e64a93db3c\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#         NOT AVAILABLE
#
#       C:\Users\siewm\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'C:\Users\siewm\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-jlgwmy0b\\numpy_6a901911fe86464997ec77e64a93db3c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\siewm\AppData\Local\Temp\pip-record-921_n2dd\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\siewm\AppData\Local\Temp\pip-build-env-n5wxinaq\overlay' --compile --install-headers 'C:\Users\siewm\AppData\Local\Temp\pip-build-env-n5wxinaq\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\siewm\anaconda3\python.exe' 'C:\Users\siewm\AppData\Local\Temp\pip-standalone-pip-y_2w780i\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\siewm\AppData\Local\Temp\pip-build-env-n5wxinaq\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\siewm\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-s4k1q1kp\\wordcloud_384ea974c48e4acaabda7d9288c59b48\\setup.py'"'"'; __file__='"'"'C:\\Users\\siewm\\AppData\\Local\\Temp\\pip-install-s4k1q1kp\\wordcloud_384ea974c48e4acaabda7d9288c59b48\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\siewm\AppData\Local\Temp\pip-wheel-f5kbe5l6'
#        cwd: C:\Users\siewm\AppData\Local\Temp\pip-install-s4k1q1kp\wordcloud_384ea974c48e4acaabda7d9288c59b48\
#   Complete output (20 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#   set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for wordcloud
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\siewm\\anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes39.dll'
# Consider using the `--user` option or check the permissions.

# %% [markdown]
# ### 1. import packages needed

# %%
import os
import pandas as pd
from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-50aadfff2c72> in <module>
#       1 import os
#       2 import pandas as pd
# ----> 3 from pycaret.classification import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %% [markdown]
# ### 2. Loading data

# %%
# set the path and data filename

path = "C:\\Users\\siewm\\OneDrive\\Desktop\\DNN practice\\data\\"
datafile = 'Video_games_esrb_rating.csv'
testdata = 'test_esrb.csv'

os.chdir(path)

# read in data

d = pd.read_csv(path+datafile)
td = pd.read_csv(path+testdata)
